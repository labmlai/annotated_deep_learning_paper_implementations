# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/transformers/switch/experiment.ipynb)
#
# ## Switch Transformer
#
# This is an experiment training Shakespeare dataset with a small Switch Transformer.

# %% [markdown]
# Install the `labml-nn` package

# %%
# !pip install labml-nn
# Out:
# Collecting labml-nn
#   Downloading https://files.pythonhosted.org/packages/fa/de/b8bea1493162cc4a845d043a84bce937f68751b9a463b2318672e0a46fed/labml_nn-0.4.79-py3-none-any.whl (117kB)
#      |████████████████████████████████| 122kB 5.3MB/s
# Collecting labml-helpers>=0.4.72
#   Downloading https://files.pythonhosted.org/packages/ec/58/2b7dcfde4565134ad97cdfe96ad7070fef95c37be2cbc066b608c9ae5c1d/labml_helpers-0.4.72-py3-none-any.whl
# Collecting labml>=0.4.86
#   Downloading https://files.pythonhosted.org/packages/cd/fb/d11117ce4b2f8bc4e592fada9b416de414e2f566b0b7c10c7304c05908f9/labml-0.4.92-py3-none-any.whl (99kB)
#      |████████████████████████████████| 102kB 5.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.19.5)
# Collecting einops
#   Downloading https://files.pythonhosted.org/packages/5d/a0/9935e030634bf60ecd572c775f64ace82ceddf2f504a5fd3902438f07090/einops-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.7.0+cu101)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from labml>=0.4.86->labml-nn) (3.13)
# Collecting gitpython
#   Downloading https://files.pythonhosted.org/packages/d7/cb/ec98155c501b68dcb11314c7992cd3df6dce193fd763084338a117967d53/GitPython-3.1.12-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 8.5MB/s
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 6.8MB/s
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Installing collected packages: smmap, gitdb, gitpython, labml, labml-helpers, einops, labml-nn
# Successfully installed einops-0.3.0 gitdb-4.0.5 gitpython-3.1.12 labml-0.4.92 labml-helpers-0.4.72 labml-nn-0.4.79 smmap-3.0.4

# %% [markdown]
# Imports

# %%
import torch
import torch.nn as nn

from labml import experiment
from labml.configs import option
from labml_helpers.module import Module
from labml_nn.transformers.switch.experiment import Configs

# %% [markdown]
# Create an experiment

# %%
experiment.create(name="switch_transformer")

# %% [markdown]
# Initialize configurations

# %%
conf = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(conf,
                # A dictionary of configurations to override
                {'tokenizer': 'character',
                'text': 'tiny_shakespeare',
                'optimizer.learning_rate': 1.,
                'optimizer.optimizer': 'Noam',
                'prompt': 'It is',
                'prompt_separator': '',

                'transformer': 'switch_transformer',
                'is_scale_prob': False,
                'n_experts': 4,

                'drop_tokens': True,
                'capacity_factor': 1.2,

                'train_loader': 'shuffled_train_loader',
                'valid_loader': 'shuffled_valid_loader',

                'seq_len': 64,
                'epochs': 128,
                'batch_size': 32,
                'inner_iterations': 25,
                })
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_pytorch_models({'model': conf.model})
# Out:
# <pre style="overflow-x: scroll;">Prepare model...
#   Prepare n_tokens...
#     Prepare text...
#       Prepare tokenizer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	3.00ms</span>
#       Download<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	347.54ms</span>
#       Load data<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	7.88ms</span>
#       Tokenize<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	31.26ms</span>
#       Build vocabulary<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	93.52ms</span>
#     Prepare text<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	501.13ms</span>
#   Prepare n_tokens<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	513.24ms</span>
#   Prepare transformer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	108.46ms</span>
#   Prepare device...
#     Prepare device_info<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	68.72ms</span>
#   Prepare device<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	72.12ms</span>
# Prepare model<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	10,419.47ms</span>
# </pre>

# %% [markdown]
# Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    conf.run()
# Out:
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">switch_transformer</span></strong>: <span style="color: #208FFB">c4656c605b9311eba13d0242ac1c0002</span>
# 	[dirty]: <strong><span style="color: #DDB62B">""</span></strong>
# Initialize...
#   Prepare mode<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	5.83ms</span>
# Initialize<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	91.16ms</span>
# Prepare validator...
#   Prepare valid_loader<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	104.91ms</span>
# <span style="color: #C5C1B4"></span>
# <span style="color: #C5C1B4">--------------------------------------------------</span><span style="color: #DDB62B"><strong><span style="text-decoration: underline"></span></strong></span>
# <span style="color: #DDB62B"><strong><span style="text-decoration: underline">LABML WARNING</span></strong></span>
# <span style="color: #DDB62B"><strong><span style="text-decoration: underline"></span></strong></span>LabML App Warning: <span style="color: #60C6C8">empty_token: </span><strong>Please create a valid token at https://app.labml.ai.</strong>
# <strong>Click on the experiment link to monitor the experiment and add it to your experiments list.</strong><span style="color: #C5C1B4"></span>
# <span style="color: #C5C1B4">--------------------------------------------------</span>
# <span style="color: #208FFB">Monitor experiment at </span><a href='https://app.labml.ai/run?uuid=c4656c605b9311eba13d0242ac1c0002' target='blank'>https://app.labml.ai/run?uuid=c4656c605b9311eba13d0242ac1c0002</a>
# Prepare validator<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	235.39ms</span>
# Prepare trainer...
#   Prepare train_loader<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	120.81ms</span>
# Prepare trainer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	164.43ms</span>
# Prepare training_loop...
#   Prepare loop_count<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	48.22ms</span>
# Prepare training_loop<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	386.33ms</span>
# <span style="color: #C5C1B4">It is</span><strong>v</strong><strong>k</strong><strong>T</strong><strong>X</strong><strong>!</strong><strong>o</strong><strong>o</strong><strong>o</strong><strong>O</strong><strong>k</strong><strong>T</strong><strong>'</strong><strong>H</strong><strong>X</strong><strong>!</strong><strong>v</strong><strong>k</strong><strong>T</strong><strong>'</strong><strong>H</strong><strong>X</strong><strong>!</strong><strong>v</strong><strong>k</strong><strong>T</strong>
# <span style="color: #C5C1B4">It is</span><strong>v</strong><strong>k</strong><strong>T</strong><strong>'</strong><strong>H</strong><strong>X</strong><strong>E</strong><strong>?</strong><strong>L</strong><strong>3</strong><strong>S</strong><strong>X</strong><strong>E</strong><strong>o</strong><strong>o</strong><strong>o</strong><strong>o</strong><strong>o</strong><strong>O</strong><strong>k</strong><strong>T</strong><strong>'</strong><strong>H</strong><strong>X</strong><strong>o</strong>
# <span style="color: #C5C1B4">It is</span><strong>e</strong><strong>$</strong><strong> </strong><strong> </strong><strong>;</strong><strong>E</strong><strong>S</strong><strong>$</strong><strong> </strong><strong>;</strong><strong>E</strong><strong>S</strong><strong>$</strong><strong> </strong><strong>;</strong><strong>E</strong><strong>S</strong><strong>$</strong><strong> </strong><strong> </strong><strong> </strong><strong> </strong><strong>c</strong><strong> </strong><strong>;</strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong> </strong><strong> </strong><strong> </strong><strong> </strong><strong> </strong><strong> </strong><strong> </strong><strong>b</strong><strong> </strong><strong>c</strong><strong> </strong><strong> </strong><strong>i</strong><strong>t</strong><strong> </strong><strong> </strong><strong> </strong><strong>c</strong><strong> </strong><strong>c</strong><strong> </strong><strong> </strong><strong> </strong><strong> </strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong> </strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong>w</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>b</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>b</strong><strong>e</strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong>
# <span style="color: #C5C1B4">It is</span><strong> </strong><strong>i</strong><strong>n</strong><strong>d</strong><strong> </strong><strong>a</strong><strong>n</strong><strong>d</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>b</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>i</strong>
# <span style="color: #C5C1B4">It is</span><strong>o</strong><strong> </strong><strong>i</strong><strong>n</strong><strong>o</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><
