# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/transformers/gpt/experiment.ipynb)
#
# ## Training a model with GPT architecture
#
# This is an experiment training Tiny Shakespeare dataset with GPT architecture model.

# %% [markdown]
# Install the `labml-nn` package

# %%
# !pip install labml-nn
# Out:
# Collecting labml-nn
#   Downloading https://files.pythonhosted.org/packages/f5/92/c454c38d613449e9cfee59809b83589bfc5463ebcf39a72126c268e31a77/labml_nn-0.4.78-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 8.4MB/s
# Collecting labml>=0.4.86
#   Downloading https://files.pythonhosted.org/packages/a7/d3/f8708934e0062e6403faa2a36d97e1677097740c94f90fd7c04ea986d7cf/labml-0.4.89-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 6.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.7.0+cu101)
# Collecting einops
#   Downloading https://files.pythonhosted.org/packages/5d/a0/9935e030634bf60ecd572c775f64ace82ceddf2f504a5fd3902438f07090/einops-0.3.0-py2.py3-none-any.whl
# Collecting labml-helpers>=0.4.72
#   Downloading https://files.pythonhosted.org/packages/ec/58/2b7dcfde4565134ad97cdfe96ad7070fef95c37be2cbc066b608c9ae5c1d/labml_helpers-0.4.72-py3-none-any.whl
# Collecting pyyaml>=5.3.1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 11.7MB/s
# Collecting gitpython
#   Downloading https://files.pythonhosted.org/packages/d7/cb/ec98155c501b68dcb11314c7992cd3df6dce193fd763084338a117967d53/GitPython-3.1.12-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 13.8MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (3.7.4.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 8.7MB/s
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=8a5f1cee9425b47a5677f6229a8cdaea31a4c0c52473052981369bc0f865efe2
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built pyyaml
# Installing collected packages: pyyaml, smmap, gitdb, gitpython, labml, einops, labml-helpers, labml-nn
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed einops-0.3.0 gitdb-4.0.5 gitpython-3.1.12 labml-0.4.89 labml-helpers-0.4.72 labml-nn-0.4.78 pyyaml-5.3.1 smmap-3.0.4

# %% [markdown]
# Imports

# %%
import torch
import torch.nn as nn

from labml import experiment
from labml.configs import option
from labml_helpers.module import Module
from labml_nn.transformers.gpt import Configs

# %% [markdown]
# Create an experiment

# %%
experiment.create(name="gpt")

# %% [markdown]
# Initialize [GPT configurations](https://nn.labml.ai/transformers/gpt/)

# %%
conf = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(conf, {
    # Use character level tokenizer
    'tokenizer': 'character',
    # Prompt separator is blank
    'prompt_separator': '',
    # Starting prompt for sampling
    'prompt': 'It is ',
    # Use Tiny Shakespeare dataset
    'text': 'tiny_shakespeare',

    # Use a context size of $128$
    'seq_len': 128,
    # Train for $32$ epochs
    'epochs': 32,
    # Batch size $128$
    'batch_size': 128,
    # Switch between training and validation for $10$ times
    # per epoch
    'inner_iterations': 10,

    # Transformer configurations
    'transformer.d_model': 512,
    'transformer.ffn.d_ff': 2048,
    'transformer.n_heads': 8,
    'transformer.n_layers': 6
})
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_pytorch_models({'model': conf.model})
# Out:
# <pre style="overflow-x: scroll;">Prepare model...
#   Prepare transformer...
#     Prepare n_tokens...
#       Prepare text...
#         Prepare tokenizer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4.91ms</span>
#         Download<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	261.22ms</span>
#         Load data<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	7.26ms</span>
#         Tokenize<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	27.96ms</span>
#         Build vocabulary<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	137.31ms</span>
#       Prepare text<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	458.67ms</span>
#     Prepare n_tokens<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	465.05ms</span>
#   Prepare transformer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	472.81ms</span>
#   Prepare encoder...
#     Prepare encoder_layer...
#       Prepare encoder_attn<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	46.65ms</span>
#       Prepare feed_forward...
#         Prepare feed_forward_activation<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4.62ms</span>
#       Prepare feed_forward<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	25.12ms</span>
#     Prepare encoder_layer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	115.91ms</span>
#   Prepare encoder<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	165.88ms</span>
#   Prepare src_embed<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	76.85ms</span>
#   Prepare generator<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	3.92ms</span>
#   Prepare device...
#     Prepare device_info<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	63.02ms</span>
#   Prepare device<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	66.20ms</span>
# Prepare model<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	11,075.54ms</span>
# </pre>

# %% [markdown]
# Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    conf.run()
# Out:
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">gpt</span></strong>: <span style="color: #208FFB">0324c6d0562111eba65d0242ac1c0002</span>
# 	[dirty]: <strong><span style="color: #DDB62B">""</span></strong>
# Initialize...
#   Prepare mode<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	2.91ms</span>
# Initialize<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	105.13ms</span>
# Prepare validator...
#   Prepare valid_loader<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	112.67ms</span>
# Prepare validator<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	259.72ms</span>
# <span style="color: #C5C1B4"></span>
# <span style="color: #C5C1B4">--------------------------------------------------</span><span style="color: #DDB62B"><strong><span style="text-decoration: underline"></span></strong></span>
# <span style="color: #DDB62B"><strong><span style="text-decoration: underline">LABML WARNING</span></strong></span>
# <span style="color: #DDB62B"><strong><span style="text-decoration: underline"></span></strong></span>LabML App Warning: <span style="color: #60C6C8">empty_token: </span><strong>Please create a valid token at https://app.labml.ai.</strong>
# <strong>Click on the experiment link to monitor the experiment and add it to your experiments list.</strong><span style="color: #C5C1B4"></span>
# <span style="color: #C5C1B4">--------------------------------------------------</span>
# <span style="color: #208FFB">Monitor experiment at </span><a href='https://app.labml.ai/run?uuid=0324c6d0562111eba65d0242ac1c0002' target='blank'>https://app.labml.ai/run?uuid=0324c6d0562111eba65d0242ac1c0002</a>
#
#   Prepare train_loader<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	105.04ms</span>
# Prepare trainer<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	207.61ms</span>
# Prepare training_loop...
#   Prepare loop_count<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	51.30ms</span>
# Prepare training_loop<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	374.91ms</span>
# <span style="color: #C5C1B4">It is </span><strong>L</strong><strong>m</strong><strong>B</strong><strong>s</strong><strong>u</strong><strong>u</strong><strong>w</strong><strong>s</strong><strong>d</strong><strong>t</strong><strong>U</strong><strong>U</strong><strong>Q</strong><strong>U</strong><strong>H</strong><strong>H</strong><strong>H</strong><strong>s</strong><strong></strong>
# <strong></strong><strong></strong>
# <strong></strong><strong></strong>
# <strong></strong><strong>B</strong><strong>s</strong><strong>Y</strong><strong>h</strong>
# <span style="color: #C5C1B4">It is </span><strong>s</strong><strong> </strong><strong>s</strong><strong> </strong><strong>a</strong><strong>n</strong><strong> </strong><strong>s</strong><strong> </strong><strong>t</strong><strong> </strong><strong>a</strong><strong> </strong><strong>a</strong><strong> </strong><strong>a</strong><strong> </strong><strong>s</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>t</strong>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>a</strong><strong>n</strong><strong>d</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>a</strong><strong>n</strong><strong>d</strong><strong> </strong><strong>a</strong><strong>n</strong><strong>d</strong><strong> </strong><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>a</strong>
# <strong><span style="color: #DDB62B">1,003,776:  </span></strong>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   303ms  </span>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  53,938ms  </span>Valid:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 1,973ms  </span> loss.train: <span style="color: #C5C1B4"> 2.38163</span> accuracy.train: <span style="color: #C5C1B4">0.250702</span> loss.valid: <span style="color: #C5C1B4"> 2.36796</span> accuracy.valid: <span style="color: #C5C1B4">0.269186</span>  <span style="color: #208FFB">61,419ms</span><span style="color: #D160C4">  0:01m/  0:31m  </span>
# <span style="color: #C5C1B4">It is </span><strong>t</strong><strong>h</strong><strong>e</strong><strong> </strong><strong>a</strong><strong>n</str
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fb962b998049> in <module>()
#       1 # Start the experiment
#       2 with experiment.start():
# ----> 3     conf.run()
#
# /usr/local/lib/python3.6/dist-packages/labml_helpers/train_valid.py in run(self)
#     238         _ = self.trainer
#     239         for _ in self.training_loop:
# --> 240             self.run_step()
#     241
#     242     def sample(self):
#
# /usr/local/lib/python3.6/dist-packages/labml_helpers/train_valid.py in run_step(self)
#     226             with self.mode.update(is_train=True):
#     227                 with tracker.namespace('train'):
# --> 228                     self.trainer()
#     229             if self.validator:
#     230                 with tracker.namespace('valid'):
#
# /usr/local/lib/python3.6/dist-packages/labml_helpers/train_valid.py in __call__(self)
#     130                 sm.on_epoch_start()
#     131         with torch.set_grad_enabled(self.mode.is_train):
# --> 132             self.__iterate()
#     133
#     134         if self._batch_index.completed:
#
# /usr/local/lib/python3.6/dist-packages/labml_helpers/train_valid.py in __iterate(self)
#     143                 batch = next(self.__iterable)
#     144
# --> 145                 self.step(batch, self._batch_index)
#     146
#     147                 self._batch_index.step()
#
# /usr/local/lib/python3.6/dist-packages/labml_nn/experiments/nlp_autoregression.py in step(self, batch, batch_idx)
#     125         # Calculate and log loss
#     126         loss = self.loss_func(output, target)
# --> 127         tracker.add("loss.", loss)
#     128
#     129         # Calculate and log accuracy
#
# /usr/local/lib/python3.6/dist-packages/labml/tracker.py in add(*args, **kwargs)
#     131         if not isinstance(args[0], str):
#     132             raise TypeError('tracker.add should be called as add(name, value), add(dictionary) or add(k=v,k2=v2...)')
# --> 133         _internal().store(args[0], args[1])
#     134
#     135
#
# /usr/local/lib/python3.6/dist-packages/labml/internal/tracker/__init__.py in store(self, key, value)
#     166
#     167         self._create_indicator(key, value)
# --> 168         self.indicators[key].collect_value(value)
#     169
#     170     def new_line(self):
#
# /usr/local/lib/python3.6/dist-packages/labml/internal/tracker/indicators/numeric.py in collect_value(self, value)
#      79
#      80     def collect_value(self, value):
# ---> 81         self._values.append(to_numpy(value).ravel())
#      82
#      83     def clear(self):
#
# /usr/local/lib/python3.6/dist-packages/labml/internal/util/values.py in to_numpy(value)
#      20             return value.data.cpu().numpy()
#      21         elif isinstance(value, torch.Tensor):
# ---> 22             return value.data.cpu().numpy()
#      23
#      24     raise ValueError(f"Unknown type {type(value)}")
#
# /usr/local/lib/python3.6/dist-packages/labml_helpers/training_loop.py in __handler(self, sig, frame)
#     162             self.__finish()
#     163             logger.log('Killing loop...', Text.danger)
# --> 164             self.old_handler(sig, frame)
#     165
#     166     def __str__(self):
#
# KeyboardInterrupt:
# <pre style="overflow-x: scroll;"><span style="color: #208FFB">Updating App. Please wait...</span></pre>
