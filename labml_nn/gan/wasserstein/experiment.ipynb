# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/gan/wasserstein/experiment.ipynb)
#
# ## DCGAN
#
# This is an experiment training DCGAN model.

# %% [markdown]
# Install the `labml-nn` package

# %%
# !pip install labml-nn
# Out:
# Collecting labml-nn
#   Downloading https://files.pythonhosted.org/packages/9d/bb/a7a6f69ab6e21de2398b5f6b0b2bb47b430e4a20ae2c8710c489e02813be/labml_nn-0.4.81-py3-none-any.whl (118kB)
#      |████████████████████████████████| 122kB 8.0MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.7.0+cu101)
# Collecting labml-helpers>=0.4.72
#   Downloading https://files.pythonhosted.org/packages/ec/58/2b7dcfde4565134ad97cdfe96ad7070fef95c37be2cbc066b608c9ae5c1d/labml_helpers-0.4.72-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.19.5)
# Collecting labml>=0.4.94
#   Downloading https://files.pythonhosted.org/packages/99/b2/3a424548d74a88ce565b38f6b7e707e7c2f00bf8c7c575a1c251807e4896/labml-0.4.94-py3-none-any.whl (99kB)
#      |████████████████████████████████| 102kB 8.2MB/s
# Collecting einops
#   Downloading https://files.pythonhosted.org/packages/5d/a0/9935e030634bf60ecd572c775f64ace82ceddf2f504a5fd3902438f07090/einops-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.16.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.8)
# Collecting gitpython
#   Downloading https://files.pythonhosted.org/packages/d7/cb/ec98155c501b68dcb11314c7992cd3df6dce193fd763084338a117967d53/GitPython-3.1.12-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 9.9MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from labml>=0.4.94->labml-nn) (3.13)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 8.6MB/s
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/d5/1e/6130925131f639b2acde0f7f18b73e33ce082ff2d90783c436b52040af5a/smmap-3.0.5-py2.py3-none-any.whl
# Installing collected packages: smmap, gitdb, gitpython, labml, labml-helpers, einops, labml-nn
# Successfully installed einops-0.3.0 gitdb-4.0.5 gitpython-3.1.12 labml-0.4.94 labml-helpers-0.4.72 labml-nn-0.4.81 smmap-3.0.5

# %% [markdown]
# Imports

# %%
from labml import experiment
from labml_nn.gan.wasserstein.experiment import Configs

# %% [markdown]
# Create an experiment

# %%
experiment.create(name="mnist_wgan")

# %% [markdown]
# Initialize configurations

# %%
conf = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(conf,
                   {
                       'discriminator': 'cnn',
                       'generator': 'cnn',
                       'label_smoothing': 0.01,
                       'generator_loss': 'wasserstein',
                       'discriminator_loss': 'wasserstein',
                   })
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Start the experiment and run the training loop.

# %%
with experiment.start():
    conf.run()
# Out:
# <pre style="overflow-x: scroll;"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0592df1e05e4> in <module>
#       1 with experiment.start():
# ----> 2     conf.run()
#       3
#
# ~/ml/labmlai/annotated_deep_learning_paper_implementations/labml_helpers/train_valid.py in run(self)
#     246         _ = self.trainer
#     247         for _ in self.training_loop:
# --> 248             self.run_step()
#     249
#     250     def sample(self):
#
# ~/ml/labmlai/annotated_deep_learning_paper_implementations/labml_helpers/train_valid.py in run_step(self)
#     234             with self.mode.update(is_train=True):
#     235                 with tracker.namespace('train'):
# --> 236                     self.trainer()
#     237             if self.validator:
#     238                 with tracker.namespace('valid'):
#
# ~/ml/labmlai/annotated_deep_learning_paper_implementations/labml_helpers/train_valid.py in __call__(self)
#     136                 sm.on_epoch_start()
#     137         with torch.set_grad_enabled(self.mode.is_train):
# --> 138             self.__iterate()
#     139
#     140         if self._batch_index.completed:
#
# ~/ml/labmlai/annotated_deep_learning_paper_implementations/labml_helpers/train_valid.py in __iterate(self)
#     147                 monit.progress(0)
#     148             while not self._batch_index.iteration_completed:
# --> 149                 batch = next(self.__iterable)
#     150
#     151                 self.step(batch, self._batch_index)
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#     104
#     105         if self.transform is not None:
# --> 106             img = self.transform(img)
#     107
#     108         if self.target_transform is not None:
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torchvision/transforms/transforms.py in forward(self, tensor)
#     224             Tensor: Normalized Tensor image.
#     225         """
# --> 226         return F.normalize(tensor, self.mean, self.std, self.inplace)
#     227
#     228     def __repr__(self):
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torchvision/transforms/functional.py in normalize(tensor, mean, std, inplace)
#     276     mean = torch.as_tensor(mean, dtype=dtype, device=tensor.device)
#     277     std = torch.as_tensor(std, dtype=dtype, device=tensor.device)
# --> 278     if (std == 0).any():
#     279         raise ValueError('std evaluated to zero after conversion to {}, leading to division by zero.'.format(dtype))
#     280     if mean.ndim == 1:
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/tensor.py in wrapped(*args, **kwargs)
#      22     def wrapped(*args, **kwargs):
#      23         from torch.overrides import has_torch_function, handle_torch_function
# ---> 24         if not all(type(t) is Tensor for t in args) and has_torch_function(args):
#      25             return handle_torch_function(wrapped, args, *args, **kwargs)
#      26         try:
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/overrides.py in has_torch_function(relevant_args)
#    1081     implementations, False otherwise.
#    1082     """
# -> 1083     return _is_torch_function_enabled() and any(
#    1084         type(a) is not torch.Tensor and
#    1085         getattr(a, '__torch_function__', _disabled_torch_function_impl)
#
# ~/miniconda/envs/torch/lib/python3.8/site-packages/torch/overrides.py in <genexpr>(.0)
#    1081     implementations, False otherwise.
#    1082     """
# -> 1083     return _is_torch_function_enabled() and any(
#    1084         type(a) is not torch.Tensor and
#    1085         getattr(a, '__torch_function__', _disabled_torch_function_impl)
#
# ~/ml/labmlai/annotated_deep_learning_paper_implementations/labml_helpers/training_loop.py in __handler(self, sig, frame)
#     162             self.__finish()
#     163             logger.log('Killing loop...', Text.danger)
# --> 164             self.old_handler(sig, frame)
#     165
#     166     def __str__(self):
#
# KeyboardInterrupt:
