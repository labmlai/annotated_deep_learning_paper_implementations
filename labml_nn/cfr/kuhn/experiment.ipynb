# %% [markdown]
# [![Github](https://img.shields.io/github/stars/lab-ml/nn?style=social)](https://github.com/lab-ml/nn)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lab-ml/nn/blob/master/labml_nn/transformers/compressive/experiment.ipynb)
#
# ## [Counterfactual Regret Minimization (CFR)](https://nn.labml.ai/cfr/index.html) on Kuhn Poker
#
# This is an experiment learning to play Kuhn Poker with Counterfactual Regret Minimization CFR algorithm.

# %% [markdown]
# Install the `labml-nn` package

# %%
# !pip install labml-nn
# Out:
# Collecting labml-nn
#   Downloading https://files.pythonhosted.org/packages/4c/22/1d55151f5b2ba65bf2241684a701ecbb5d3d88ba70a2761ac64a7a7d40ba/labml_nn-0.4.89-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 16.4MB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.19.5)
# Collecting einops
#   Downloading https://files.pythonhosted.org/packages/5d/a0/9935e030634bf60ecd572c775f64ace82ceddf2f504a5fd3902438f07090/einops-0.3.0-py2.py3-none-any.whl
# Collecting labml>=0.4.103
#   Downloading https://files.pythonhosted.org/packages/31/14/ffed9b2bd050230ee774ac178576da9152a753351a18e98e095128781af7/labml-0.4.103-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 12.3MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from labml-nn) (1.7.0+cu101)
# Collecting labml-helpers>=0.4.76
#   Downloading https://files.pythonhosted.org/packages/49/df/4d920a4a221acd3cfa384dddb909ed0691b08682c0d8aeaabeee2138624f/labml_helpers-0.4.76-py3-none-any.whl
# Collecting gitpython
#   Downloading https://files.pythonhosted.org/packages/fb/67/47a04d8a9d7f94645676fe683f1ee3fe9be01fe407686c180768a92abaac/GitPython-3.1.13-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 49.5MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from labml>=0.4.103->labml-nn) (3.13)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (3.7.4.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->labml-nn) (0.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 12.3MB/s
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/d5/1e/6130925131f639b2acde0f7f18b73e33ce082ff2d90783c436b52040af5a/smmap-3.0.5-py2.py3-none-any.whl
# Installing collected packages: einops, smmap, gitdb, gitpython, labml, labml-helpers, labml-nn
# Successfully installed einops-0.3.0 gitdb-4.0.5 gitpython-3.1.13 labml-0.4.103 labml-helpers-0.4.76 labml-nn-0.4.89 smmap-3.0.5

# %% [markdown]
# Imports

# %%
from labml import experiment, analytics
from labml_nn.cfr.analytics import plot_infosets
from labml_nn.cfr.kuhn import Configs
from labml_nn.cfr.infoset_saver import InfoSetSaver

# %% [markdown]
# Create an experiment, we only write tracking information to `sqlite` to speed things up.
# Since the algorithm iterates fast and we track data on each iteration, writing to
# other destinations such as Tensorboard can be relatively time consuming.
# SQLite is enough for our analytics.

# %%
experiment.create(name='kuhn_poker', writers={'sqlite', 'screen'})

# %% [markdown]
# Initialize configurations

# %%
conf = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(conf)
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_model_savers({'info_sets': InfoSetSaver(conf.cfr.info_sets)})
# Out:
# <pre style="overflow-x: scroll;">Prepare cfr...
#   Prepare create_new_history<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	4.53ms</span>
# Prepare cfr<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	9.95ms</span>
# </pre>

# %% [markdown]
# Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    conf.cfr.iterate()
# Out:
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">kuhn_poker</span></strong>: <span style="color: #208FFB">0894ac10d25011ebaa31acde48001122</span>
# 	[dirty]: <strong><span style="color: #DDB62B">"docs"</span></strong>
# <strong><span style="color: #DDB62B">     999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  1ms  </span>  <span style="color: #208FFB">5ms</span><span style="color: #D160C4">  0:00m/  0:08m  </span>
# <strong><span style="color: #DDB62B">   1,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  1ms  </span>  <span style="color: #208FFB">5ms</span><span style="color: #D160C4">  0:00m/  0:08m  </span>
# <strong><span style="color: #DDB62B">   2,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  1ms  </span>  <span style="color: #208FFB">6ms</span><span style="color: #D160C4">  0:00m/  0:09m  </span>
# <strong><span style="color: #DDB62B">   3,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  1ms  </span>  <span style="color: #208FFB">6ms</span><span style="color: #D160C4">  0:00m/  0:09m  </span>
# <strong><span style="color: #DDB62B">   4,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  2ms  </span>  <span style="color: #208FFB">6ms</span><span style="color: #D160C4">  0:00m/  0:10m  </span>
# <strong><span style="color: #DDB62B">   5,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  2ms  </span>  <span style="color: #208FFB">6ms</span><span style="color: #D160C4">  0:00m/  0:09m  </span>
# <strong><span style="color: #DDB62B">   6,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  2ms  </span>  <span style="color: #208FFB">7ms</span><span style="color: #D160C4">  0:00m/  0:11m  </span>
# <strong><span style="color: #DDB62B">   7,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">11ms</span><span style="color: #D160C4">  0:00m/  0:16m  </span>
# <strong><span style="color: #DDB62B">   8,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  2ms  </span>  <span style="color: #208FFB">7ms</span><span style="color: #D160C4">  0:01m/  0:10m  </span>
# <strong><span style="color: #DDB62B">   9,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  2ms  </span>  <span style="color: #208FFB">7ms</span><span style="color: #D160C4">  0:01m/  0:11m  </span>
# <strong><span style="color: #DDB62B">  10,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">10ms</span><span style="color: #D160C4">  0:01m/  0:15m  </span>
# <strong><span style="color: #DDB62B">  11,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">13ms</span><span style="color: #D160C4">  0:01m/  0:19m  </span>
# <strong><span style="color: #DDB62B">  12,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">11ms</span><span style="color: #D160C4">  0:01m/  0:17m  </span>
# <strong><span style="color: #DDB62B">  13,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">10ms</span><span style="color: #D160C4">  0:01m/  0:14m  </span>
# <strong><span style="color: #DDB62B">  14,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  2ms  </span>  <span style="color: #208FFB">8ms</span><span style="color: #D160C4">  0:01m/  0:11m  </span>
# <strong><span style="color: #DDB62B">  15,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">11ms</span><span style="color: #D160C4">  0:02m/  0:15m  </span>
# <strong><span style="color: #DDB62B">  16,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">10ms</span><span style="color: #D160C4">  0:02m/  0:14m  </span>
# <strong><span style="color: #DDB62B">  17,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">10ms</span><span style="color: #D160C4">  0:02m/  0:14m  </span>
# <strong><span style="color: #DDB62B">  18,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">11ms</span><span style="color: #D160C4">  0:02m/  0:15m  </span>
# <strong><span style="color: #DDB62B">  19,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">11ms</span><span style="color: #D160C4">  0:02m/  0:14m  </span>
# <strong><span style="color: #DDB62B">  20,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">10ms</span><span style="color: #D160C4">  0:02m/  0:13m  </span>
# <strong><span style="color: #DDB62B">  21,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">12ms</span><span style="color: #D160C4">  0:03m/  0:15m  </span>
# <strong><span style="color: #DDB62B">  22,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  5ms  </span>  <span style="color: #208FFB">18ms</span><span style="color: #D160C4">  0:03m/  0:27m  </span>
# <strong><span style="color: #DDB62B">  23,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  5ms  </span>  <span style="color: #208FFB">14ms</span><span style="color: #D160C4">  0:03m/  0:20m  </span>
# <strong><span style="color: #DDB62B">  24,999:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  3ms  </span>  <span style="color: #208FFB">13ms</span><span style="color: #D160C4">  0:03m/  0:17m  </span>
# <strong><span style="color: #DDB62B">  25,597:  </span></strong>Track:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">  4ms  </span>  <span style="color: #208FFB">12ms</span><span style="color: #D160C4">  0:04m/  0:16m  </span></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-57116c6aa4cd> in <module>
#       1 # Start the experiment
#       2 with experiment.start():
# ----> 3     conf.cfr.iterate()
#
# ~/ml/lab-ml/nn/labml_nn/cfr/__init__.py in iterate(self)
#     681
#     682             # Track data for analytics
# --> 683             self.tracker(self.info_sets)
#     684             tracker.save()
#     685
#
# ~/ml/lab-ml/nn/labml_nn/cfr/__init__.py in __call__(self, info_sets)
#     718                         f'strategy.{I.key}.{a}': I.strategy[a],
#     719                         f'average_strategy.{I.key}.{a}': avg_strategy[a],
# --> 720                         f'regret.{I.key}.{a}': I.regret[a],
#     721                     })
#     722
#
# ~/ml/lab-ml/nn/labml/internal/monitor/sections.py in __exit__(self, exc_type, exc_val, exc_tb)
#      83         self.track_progress()
#      84
# ---> 85         self._monitor.section_exit(self)
#      86
#      87     def track_progress(self):
#
# ~/ml/lab-ml/nn/labml/internal/monitor/__init__.py in section_exit(self, section)
#     202             raise RuntimeError("Impossible")
#     203
# --> 204         self.__log_line()
#     205         self.__sections.pop(-1)
#     206
#
# ~/ml/lab-ml/nn/labml/internal/monitor/__init__.py in __log_line(self)
#     178     def __log_line(self):
#     179         if self.__is_looping:
# --> 180             self.__log_looping_line()
#     181             return
#     182
#
# ~/ml/lab-ml/nn/labml/internal/monitor/__init__.py in __log_looping_line(self)
#     174
#     175         if not self.__is_silent:
# --> 176             logger().log(parts, is_new_line=False)
#     177
#     178     def __log_line(self):
#
# ~/ml/lab-ml/nn/labml/internal/logger/__init__.py in log(self, parts, is_new_line, is_reset)
#      22             is_reset: bool = True):
#      23         for d in self.__destinations:
# ---> 24             d.log(parts, is_new_line=is_new_line, is_reset=is_reset)
#      25
#      26     def info(self, *args, **kwargs):
#
# ~/ml/lab-ml/nn/labml/internal/logger/destinations/console.py in log(self, parts, is_new_line, is_reset)
#      41
#      42         if is_reset:
# ---> 43             self.print("\r" + text, end_char)
#      44         else:
#      45             print(text, end_char)
#
# ~/ml/lab-ml/nn/labml/internal/logger/destinations/console.py in print(self, text, end_char)
#      49             print(text, end=end_char, flush=True)
#      50         else:
# ---> 51             API_LOGS.outputs(logger_=text + end_char)
#
# ~/ml/lab-ml/nn/labml/internal/api/logs.py in outputs(self, stdout_, stderr_, logger_)
#      61                 self.data['stderr'] = self.data.get('stderr', '') + stderr_
#      62             if logger_ != '':
# ---> 63                 self.data['logger'] = self.data.get('logger', '') + logger_
#      64
#      65         self.check_and_flush()
#
# KeyboardInterrupt:

# %%
inds = analytics.runs(experiment.get_uuid())

# %%
dir(inds)
# Out:
# ['average_strategy_A_b',
#  'average_strategy_A_p',
#  'average_strategy_Ab_b',
#  'average_strategy_Ab_p',
#  'average_strategy_K_b',
#  'average_strategy_K_p',
#  'average_strategy_Kb_b',
#  'average_strategy_Kb_p',
#  'average_strategy_Q_b',
#  'average_strategy_Q_p',
#  'average_strategy_Qb_b',
#  'average_strategy_Qb_p',
#  'regret_A_b',
#  'regret_A_p',
#  'regret_Ab_b',
#  'regret_Ab_p',
#  'regret_K_b',
#  'regret_K_p',
#  'regret_Kb_b',
#  'regret_Kb_p',
#  'regret_Q_b',
#  'regret_Q_p',
#  'regret_Qb_b',
#  'regret_Qb_p',
#  'strategy_A_b',
#  'strategy_A_p',
#  'strategy_Ab_b',
#  'strategy_Ab_p',
#  'strategy_K_b',
#  'strategy_K_p',
#  'strategy_Kb_b',
#  'strategy_Kb_p',
#  'strategy_Q_b',
#  'strategy_Q_p',
#  'strategy_Qb_b',
#  'strategy_Qb_p',
#  'time_Track',
#  'time_loop']

# %%
plot_infosets(inds['average_strategy.*'], width=600, height=500).display()
# Out:
# alt.Chart(...)

# %%
analytics.scatter(inds.average_strategy_Q_b, inds.average_strategy_Kb_b,
                  width=400, height=400)
# Out:
# alt.VConcatChart(...)
